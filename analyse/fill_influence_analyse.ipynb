# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
def violinplot(data, x=None, y=None, hue=None, pairs=None, xlabel=None, ylabel=None, xticklabels=None, output_path: str = None, figsize: tuple = (24, 12)):
    sns.set_theme(style="whitegrid")

    fig, ax = plt.subplots(figsize=figsize)

    ax = sns.violinplot(data=data, x=x, y=y, hue=hue)

    if pairs:
        annotator = Annotator(ax, pairs, data=data, x=x, y=y, hue=hue)
        annotator.configure(test='Mann-Whitney', text_format='star')
        annotator.apply_and_annotate()

    plt.legend()
    plt.grid(False)

    if xlabel is not None:
        plt.xlabel(xlabel)
    if ylabel is not None:
        plt.ylabel(ylabel)
    if xticklabels:
        ax.set_xticklabels(labels=xticklabels)

    if output_path:
        plt.savefig(output_path, bbox_inches="tight")
    plt.show()

# %%
def read_accuracy(dir_path: str):
    acc = {}
    for target in ['minor', 'important', 'full', 'all']:
        acc[target] = pd.read_csv(os.path.join(dir_path, 'accuracy_{}.csv'.format(target)), index_col=0)
    return acc

control_acc = read_accuracy('../output/control')
miNNseq_acc = read_accuracy('../output/miNNseq')

# %%
for target in ['minor', 'important', 'full', 'all']:
    _control_acc = pd.melt(control_acc[target], value_vars=control_acc[target].columns)
    _miNNseq_acc = pd.melt(miNNseq_acc[target], value_vars=miNNseq_acc[target].columns)

    _control_acc['category'] = 'control'
    _miNNseq_acc['category'] = 'miNNseq'

    pairs = [
        ((method_name, 'control'), (method_name, 'miNNseq'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'miNNseq'), ('ExtraTreesClassifier', 'miNNseq')),
    ])

    violinplot(
        pd.concat([_control_acc, _miNNseq_acc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='Accuracy',
        output_path='../output/miNNseq/accuracy_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:8.836e-03 U_stat=8.700e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.463e-01 U_stat=1.113e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.181e-01 U_stat=1.071e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.980e-01 U_stat=1.127e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.466e-04 U_stat=1.769e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:7.212e-03 U_stat=1.640e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.181e-02 U_stat=1.614e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.076e-03 U_stat=1.679e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.802e-01 U_stat=1.093e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:9.203e-01 U_stat=1.265e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:4.048e-03 U_stat=8.330e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.115e-04 U_stat=7.460e+02
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.013e-01 U_stat=1.348e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.089e-02 U_stat=9.150e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:2.991e-01 U_stat=1.100e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.698e-01 U_stat=1.051e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.153e-01 U_stat=1.430e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.643e-01 U_stat=1.048e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.306e-02 U_stat=1.610e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.782e-01 U_stat=1.331e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:6.816e-01 U_stat=1.190e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.424e-04 U_stat=7.185e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:9.613e-01 U_stat=1.258e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:4.217e-02 U_stat=9.560e+02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.054e-01 U_stat=1.153e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.743e-01 U_stat=1.409e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.921e-01 U_stat=1.060e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.358e-01 U_stat=1.034e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.505e-02 U_stat=1.603e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:8.083e-09 U_stat=4.220e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:4.446e-01 U_stat=1.361e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.260e-01 U_stat=1.392e+03

# %%
def read_roc(dir_path: str):
    roc = {}
    for target in ['minor', 'important', 'full', 'all']:
        roc[target] = np.load(os.path.join(dir_path, 'ROC_{}.npy'.format(target)), allow_pickle=True)
    return roc

control_roc = read_roc('../output/control')
miNNseq_roc = read_roc('../output/miNNseq')

# %%
for target in ['minor', 'important', 'full', 'all']:
    _control_roc = control_roc[target].item()
    _miNNseq_roc = miNNseq_roc[target].item()

    _control_roc = pd.DataFrame(
        [
            _control_roc[method_name][2]
            for method_name in _control_roc.keys()
        ],
        index=_control_roc.keys()
    ).T
    _miNNseq_roc = pd.DataFrame(
        [
            _miNNseq_roc[method_name][2]
            for method_name in _miNNseq_roc.keys()
        ],
        index=_miNNseq_roc.keys()
    ).T

    _control_roc = pd.melt(_control_roc, value_vars=_control_roc.columns)
    _miNNseq_roc = pd.melt(_miNNseq_roc, value_vars=_miNNseq_roc.columns)

    _control_roc['category'] = 'control'
    _miNNseq_roc['category'] = 'miNNseq'

    pairs = [
        ((method_name, 'control'), (method_name, 'miNNseq'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'miNNseq'), ('ExtraTreesClassifier', 'miNNseq')),
    ])

    violinplot(
        pd.concat([_control_roc, _miNNseq_roc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='ROC-AUC',
        output_path='../output/miNNseq/auc_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.526e-01 U_stat=1.042e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.103e-01 U_stat=1.154e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:7.381e-01 U_stat=1.201e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.327e-01 U_stat=1.109e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.251e-01 U_stat=1.473e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.075e-01 U_stat=1.484e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:3.703e-02 U_stat=1.553e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.845e-01 U_stat=1.443e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:9.753e-01 U_stat=1.245e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.539e-01 U_stat=1.416e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.090e-01 U_stat=1.017e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.962e-02 U_stat=9.110e+02
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.467e-01 U_stat=1.387e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:9.313e-01 U_stat=1.237e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:4.219e-01 U_stat=1.367e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:9.505e-01 U_stat=1.260e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:9.259e-01 U_stat=1.236e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.147e-02 U_stat=9.670e+02
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:3.027e-01 U_stat=1.400e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:6.368e-01 U_stat=1.319e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.649e-01 U_stat=1.166e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:8.067e-01 U_stat=1.214e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:3.945e-01 U_stat=1.126e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:4.826e-02 U_stat=9.630e+02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:4.905e-02 U_stat=9.640e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:2.354e-02 U_stat=1.579e+03
# RandomForestClassifier_control vs. RandomForestClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:8.797e-02 U_stat=1.002e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:4.798e-01 U_stat=1.147e+03
# SVC_control vs. SVC_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:5.185e-04 U_stat=1.754e+03
# OrderedModel_control vs. OrderedModel_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:1.302e-01 U_stat=1.030e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.938e-01 U_stat=1.439e+03
# RandomForestClassifier_miNNseq vs. ExtraTreesClassifier_miNNseq: Mann-Whitney-Wilcoxon test two-sided, P_val:7.870e-03 U_stat=1.636e+03
