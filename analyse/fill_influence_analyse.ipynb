# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
def violinplot(data, x=None, y=None, hue=None, pairs=None, xlabel=None, ylabel=None, xticklabels=None, output_path: str = None, figsize: tuple = (24, 12)):
    sns.set_theme(style="whitegrid")

    fig, ax = plt.subplots(figsize=figsize)

    ax = sns.violinplot(data=data, x=x, y=y, hue=hue)

    if pairs:
        annotator = Annotator(ax, pairs, data=data, x=x, y=y, hue=hue)
        annotator.configure(test='Mann-Whitney', text_format='star')
        annotator.apply_and_annotate()

    plt.legend()
    plt.grid(False)

    if xlabel is not None:
        plt.xlabel(xlabel)
    if ylabel is not None:
        plt.ylabel(ylabel)
    if xticklabels:
        ax.set_xticklabels(labels=xticklabels)

    if output_path:
        plt.savefig(output_path, bbox_inches="tight")
    plt.show()

# %%
def read_accuracy(dir_path: str):
    acc = {}
    for target in ['effective', 'markedly effective', 'cured', 'all']:
        acc[target] = pd.read_csv(os.path.join(dir_path, 'accuracy_{}.csv'.format(target)), index_col=0)
    return acc

control_acc = read_accuracy('../output/control')
KNN_acc = read_accuracy('../output/data_fill/KNN')
rpca_acc = read_accuracy('../output/data_fill/rpca')

# %%
for target in ['effective', 'markedly effective', 'cured', 'all']:
    _control_acc = pd.melt(control_acc[target], value_vars=control_acc[target].columns)
    _KNN_acc = pd.melt(KNN_acc[target], value_vars=KNN_acc[target].columns)

    _control_acc['category'] = 'control'
    _KNN_acc['category'] = 'KNN'

    pairs = [
        ((method_name, 'control'), (method_name, 'KNN'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'KNN'), ('ExtraTreesClassifier', 'KNN')),
    ])

    violinplot(
        pd.concat([_control_acc, _KNN_acc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='Accuracy',
        output_path='../output/data_fill/KNN/accuracy_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.678e-01 U_stat=1.119e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.109e-02 U_stat=9.370e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.982e-01 U_stat=1.437e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.551e-02 U_stat=1.528e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.295e-04 U_stat=7.160e+02
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.412e-04 U_stat=7.480e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.000e+00 U_stat=1.250e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.167e-01 U_stat=1.323e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.287e-02 U_stat=1.531e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.429e-02 U_stat=1.542e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.118e-01 U_stat=1.481e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.595e-02 U_stat=1.517e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.322e-01 U_stat=1.341e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.322e-01 U_stat=1.341e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:8.708e-01 U_stat=1.226e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.917e-01 U_stat=1.248e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.454e-04 U_stat=6.990e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.195e-09 U_stat=3.980e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.285e-03 U_stat=7.830e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:8.247e-04 U_stat=7.650e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.580e-04 U_stat=7.200e+02
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.580e-04 U_stat=7.200e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:3.623e-01 U_stat=1.118e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.384e-01 U_stat=1.111e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.818e-02 U_stat=9.490e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.680e-01 U_stat=1.119e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.294e-01 U_stat=1.365e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.862e-01 U_stat=1.253e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.771e-01 U_stat=1.092e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.771e-01 U_stat=1.092e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:2.794e-02 U_stat=1.568e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.210e-01 U_stat=1.475e+03

# %%
def read_roc(dir_path: str):
    roc = {}
    for target in ['effective', 'markedly effective', 'cured', 'all']:
        roc[target] = np.load(os.path.join(dir_path, 'ROC_{}.npy'.format(target)), allow_pickle=True)
    return roc

control_roc = read_roc('../output/control')
KNN_roc = read_roc('../output/data_fill/KNN')
rpca_roc = read_roc('../output/data_fill/rpca')

# %%
for target in ['effective', 'markedly effective', 'cured', 'all']:
    _control_roc = control_roc[target].item()
    _KNN_roc = KNN_roc[target].item()

    _control_roc = pd.DataFrame(
        [
            _control_roc[method_name][2]
            for method_name in _control_roc.keys()
        ],
        index=_control_roc.keys()
    ).T
    _KNN_roc = pd.DataFrame(
        [
            _KNN_roc[method_name][2]
            for method_name in _KNN_roc.keys()
        ],
        index=_KNN_roc.keys()
    ).T

    _control_roc = pd.melt(_control_roc, value_vars=_control_roc.columns)
    _KNN_roc = pd.melt(_KNN_roc, value_vars=_KNN_roc.columns)

    _control_roc['category'] = 'control'
    _KNN_roc['category'] = 'KNN'

    pairs = [
        ((method_name, 'control'), (method_name, 'KNN'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'KNN'), ('ExtraTreesClassifier', 'KNN')),
    ])

    violinplot(
        pd.concat([_control_roc, _KNN_roc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='ROC-AUC',
        output_path='../output/data_fill/KNN/auc_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.867e-01 U_stat=1.191e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.448e-01 U_stat=1.038e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.462e-01 U_stat=1.361e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.520e-04 U_stat=1.745e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.417e-01 U_stat=1.318e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.667e-02 U_stat=9.280e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:5.327e-01 U_stat=1.159e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.105e-01 U_stat=1.482e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.839e-04 U_stat=1.777e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.989e-03 U_stat=1.699e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.364e-03 U_stat=1.664e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.098e-03 U_stat=1.724e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.392e-01 U_stat=1.035e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.034e-01 U_stat=1.435e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:3.946e-01 U_stat=1.126e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.418e-01 U_stat=1.161e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.658e-07 U_stat=5.030e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.257e-03 U_stat=8.720e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.766e-02 U_stat=9.480e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.221e-02 U_stat=8.860e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.023e-01 U_stat=1.372e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.770e-03 U_stat=1.704e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.198e-02 U_stat=8.850e+02
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.233e-03 U_stat=8.060e+02
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.344e-02 U_stat=9.410e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.926e-02 U_stat=1.590e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.556e-01 U_stat=1.164e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.329e-01 U_stat=1.200e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.344e-01 U_stat=1.423e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.656e-03 U_stat=1.661e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:7.801e-01 U_stat=1.291e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.860e-01 U_stat=1.330e+03

# %%
def boxplot(data, x=None, y=None, hue=None, pairs=None, xlabel=None, ylabel=None, xticklabels=None, output_path: str = None, figsize: tuple = (24, 12)):
    sns.set_theme(style="whitegrid")

    fig, ax = plt.subplots(figsize=figsize)

    ax = sns.boxplot(data=data, x=x, y=y, hue=hue)

    if pairs:
        annotator = Annotator(ax, pairs, data=data, x=x, y=y, hue=hue)
        annotator.configure(test='Mann-Whitney', text_format='star')
        annotator.apply_and_annotate()

    plt.legend()
    plt.grid(False)

    if xlabel is not None:
        plt.xlabel(xlabel)
        plt.xticks(rotation=90)
    if ylabel is not None:
        plt.ylabel(ylabel)
    if xticklabels:
        ax.set_xticklabels(labels=xticklabels)

    if output_path:
        plt.savefig(output_path, bbox_inches="tight")
    plt.show()

# %%
control_RF_feature_importance = pd.read_csv('../output/control/RF_feature_importance.csv', header=[0, 1, 2])
KNN_RF_feature_importance = pd.read_csv('../output/data_fill/KNN/RF_feature_importance.csv', header=[0, 1, 2])

control_RF_feature_importance.columns = ['-'.join([item for item in col if 'Unnamed' not in item]) for col in control_RF_feature_importance.columns.values]
KNN_RF_feature_importance.columns = ['-'.join([item for item in col if 'Unnamed' not in item]) for col in KNN_RF_feature_importance.columns.values]

control_RF_feature_importance = control_RF_feature_importance.drop(["id"], axis=1)
KNN_RF_feature_importance = KNN_RF_feature_importance.drop(["id"], axis=1)

# %%
boxplot(
    pd.melt(control_RF_feature_importance, value_vars=control_RF_feature_importance.reset_index().columns.drop(['index', 'target']), id_vars=['target']),
    x='variable',
    y='value',
    hue='target',
    pairs=[
        (('age', 'cured'), ('age', 'effective')),
        (('age', 'cured'), ('age', 'markedly effective')),
        (('age', 'cured'), ('age', 'all')),

        (('time of onset', 'cured'), ('time of onset', 'effective')),
        (('time of onset', 'cured'), ('time of onset', 'markedly effective')),
        (('time of onset', 'cured'), ('time of onset', 'all')),

        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'effective')),
        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'markedly effective')),
        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'all')),

        (('ABR', 'cured'), ('ABR', 'effective')),
        (('ABR', 'cured'), ('ABR', 'markedly effective')),
        (('ABR', 'cured'), ('ABR', 'all')),

        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'effective')),
        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'markedly effective')),
        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'all')),
    ],
    xlabel='',
    ylabel='Importance score',
    output_path='../output/control/RF_feature_importance.pdf',
)
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# otoacoustic emission (500-6000Hz)_cured vs. otoacoustic emission (500-6000Hz)_all: Mann-Whitney-Wilcoxon test two-sided, P_val:7.969e-18 U_stat=2.498e+03
# treatment plan-tympanic injection_cured vs. treatment plan-tympanic injection_all: Mann-Whitney-Wilcoxon test two-sided, P_val:4.055e-06 U_stat=1.919e+03
# ABR_cured vs. ABR_all: Mann-Whitney-Wilcoxon test two-sided, P_val:1.349e-16 U_stat=2.450e+03
# time of onset_cured vs. time of onset_all: Mann-Whitney-Wilcoxon test two-sided, P_val:1.049e-15 U_stat=8.600e+01
# age_cured vs. age_all: Mann-Whitney-Wilcoxon test two-sided, P_val:1.007e-14 U_stat=2.373e+03
# age_markedly effective vs. age_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:5.699e-13 U_stat=2.040e+02
# time of onset_markedly effective vs. time of onset_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.504e-18 U_stat=2.499e+03
# treatment plan-tympanic injection_markedly effective vs. treatment plan-tympanic injection_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:4.089e-11 U_stat=2.920e+02
# ABR_markedly effective vs. ABR_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# otoacoustic emission (500-6000Hz)_markedly effective vs. otoacoustic emission (500-6000Hz)_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# time of onset_effective vs. time of onset_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=2.500e+03
# age_effective vs. age_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:1.349e-16 U_stat=5.000e+01
# treatment plan-tympanic injection_effective vs. treatment plan-tympanic injection_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:1.485e-08 U_stat=4.280e+02
# ABR_effective vs. ABR_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# otoacoustic emission (500-6000Hz)_effective vs. otoacoustic emission (500-6000Hz)_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00

# %%
boxplot(
    pd.melt(KNN_RF_feature_importance, value_vars=KNN_RF_feature_importance.reset_index().columns.drop(['index', 'target']), id_vars=['target']),
    x='variable',
    y='value',
    hue='target',
    pairs=[
        (('age', 'cured'), ('age', 'effective')),
        (('age', 'cured'), ('age', 'markedly effective')),
        (('age', 'cured'), ('age', 'all')),

        (('time of onset', 'cured'), ('time of onset', 'effective')),
        (('time of onset', 'cured'), ('time of onset', 'markedly effective')),
        (('time of onset', 'cured'), ('time of onset', 'all')),

        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'effective')),
        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'markedly effective')),
        (('treatment plan-tympanic injection', 'cured'), ('treatment plan-tympanic injection', 'all')),

        (('ABR', 'cured'), ('ABR', 'effective')),
        (('ABR', 'cured'), ('ABR', 'markedly effective')),
        (('ABR', 'cured'), ('ABR', 'all')),

        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'effective')),
        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'markedly effective')),
        (('otoacoustic emission (500-6000Hz)', 'cured'), ('otoacoustic emission (500-6000Hz)', 'all')),
    ],
    xlabel='',
    ylabel='Importance score',
    output_path='../output/data_fill/KNN/RF_feature_importance.pdf',
)
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# otoacoustic emission (500-6000Hz)_cured vs. otoacoustic emission (500-6000Hz)_all: Mann-Whitney-Wilcoxon test two-sided, P_val:7.504e-18 U_stat=2.499e+03
# treatment plan-tympanic injection_cured vs. treatment plan-tympanic injection_all: Mann-Whitney-Wilcoxon test two-sided, P_val:1.185e-14 U_stat=2.370e+03
# ABR_cured vs. ABR_all: Mann-Whitney-Wilcoxon test two-sided, P_val:7.504e-18 U_stat=2.499e+03
# time of onset_cured vs. time of onset_all: Mann-Whitney-Wilcoxon test two-sided, P_val:1.728e-14 U_stat=1.370e+02
# age_cured vs. age_all: Mann-Whitney-Wilcoxon test two-sided, P_val:9.636e-03 U_stat=1.626e+03
# age_markedly effective vs. age_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:3.060e-01 U_stat=1.101e+03
# time of onset_markedly effective vs. time of onset_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:8.985e-18 U_stat=2.496e+03
# treatment plan-tympanic injection_markedly effective vs. treatment plan-tympanic injection_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:5.318e-17 U_stat=3.400e+01
# ABR_markedly effective vs. ABR_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# otoacoustic emission (500-6000Hz)_markedly effective vs. otoacoustic emission (500-6000Hz)_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# time of onset_effective vs. time of onset_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=2.500e+03
# age_effective vs. age_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:2.900e-01 U_stat=1.404e+03
# treatment plan-tympanic injection_effective vs. treatment plan-tympanic injection_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:5.639e-17 U_stat=3.500e+01
# ABR_effective vs. ABR_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
# otoacoustic emission (500-6000Hz)_effective vs. otoacoustic emission (500-6000Hz)_cured: Mann-Whitney-Wilcoxon test two-sided, P_val:7.066e-18 U_stat=0.000e+00
