# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
def violinplot(data, x=None, y=None, hue=None, pairs=None, xlabel=None, ylabel=None, xticklabels=None, output_path: str = None, figsize: tuple = (24, 12)):
    sns.set_theme(style="whitegrid")

    fig, ax = plt.subplots(figsize=figsize)

    ax = sns.violinplot(data=data, x=x, y=y, hue=hue)

    if pairs:
        annotator = Annotator(ax, pairs, data=data, x=x, y=y, hue=hue)
        annotator.configure(test='Mann-Whitney', text_format='star', loc='outside', comparisons_correction="Bonferroni")
        annotator.apply_and_annotate()

    plt.legend()
    plt.grid(False)

    if xlabel is not None:
        plt.xlabel(xlabel)
    if ylabel is not None:
        plt.ylabel(ylabel)
    if xticklabels:
        ax.set_xticklabels(labels=xticklabels)

    if output_path:
        plt.savefig(output_path, bbox_inches="tight")
    plt.show()

# %%
def read_accuracy(dir_path: str):
    acc = {}
    for target in ['minor', 'important', 'full', 'all']:
        acc[target] = pd.read_csv(os.path.join(dir_path, 'accuracy_{}.csv'.format(target)), index_col=0)
    return acc

control_acc = read_accuracy('../output/control')
miNNseq_acc = read_accuracy('../output/miNNseq')

# %%
for target in ['minor', 'important', 'full', 'all']:
    _miNNseq_acc = pd.melt(miNNseq_acc[target], value_vars=miNNseq_acc[target].columns)

    methods = miNNseq_acc[target].columns
    pairs = [
        (methods[i], methods[j])
        for i in range(len(methods))
        for j in range(i + 1, len(methods))
    ]

    violinplot(
        _miNNseq_acc,
        x='variable',
        y='value',
        pairs=pairs,
        xlabel='',
        ylabel='Accuracy',
        output_path='../output/miNNseq/accuracy_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.312e-10 U_stat=2.605e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.461e-01 U_stat=9.020e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.614e-02 U_stat=1.679e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.076e-16 U_stat=2.499e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.966e-11 U_stat=2.215e+02
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.271e-14 U_stat=1.170e+02
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.337e+03
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.015e-16 U_stat=2.500e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.096e-13 U_stat=2.350e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.697e-10 U_stat=2.660e+02
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.142e-16 U_stat=2.498e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.462e-15 U_stat=2.432e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.137e-14 U_stat=2.419e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.418e-13 U_stat=2.357e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.044e-02 U_stat=1.714e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.684e-11 U_stat=2.195e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.097e+03
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.051e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.011e-16 U_stat=2.500e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.287e-16 U_stat=5.500e+00
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.066e-11 U_stat=2.100e+02
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.290e-01 U_stat=8.695e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.002e-16 U_stat=2.500e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.853e-15 U_stat=2.449e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.044e-13 U_stat=1.600e+02
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.012e-16 U_stat=2.500e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.782e-15 U_stat=2.450e+03
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.269e-16 U_stat=2.496e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.008e-16 U_stat=2.475e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.079e-05 U_stat=1.922e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.529e-01 U_stat=8.780e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.120e+03
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.325e-01 U_stat=9.560e+02
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.862e-17 U_stat=2.500e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.092e-16 U_stat=2.000e+00
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.454e-03 U_stat=7.170e+02
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.331e-01 U_stat=8.715e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.114e-16 U_stat=2.498e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.904e-11 U_stat=2.277e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.041e-06 U_stat=4.695e+02
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.050e-16 U_stat=2.500e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.244e-08 U_stat=2.124e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.459e-16 U_stat=2.494e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.159e-05 U_stat=1.965e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.619e-01 U_stat=1.594e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.335e-14 U_stat=8.400e+01
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.834e-04 U_stat=6.640e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.392e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.167e-16 U_stat=2.498e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.646e-13 U_stat=1.555e+02
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.152e-15 U_stat=4.100e+01
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.877e-03 U_stat=6.945e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.115e-16 U_stat=2.498e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.947e-17 U_stat=2.498e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.833e-16 U_stat=3.850e+01
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.286e-16 U_stat=2.496e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.550e-17 U_stat=2.500e+03
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.472e-08 U_stat=2.116e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.245e-17 U_stat=2.500e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.561e-02 U_stat=8.110e+02

# %%
def read_roc(dir_path: str):
    roc = {}
    for target in ['minor', 'important', 'full', 'all']:
        roc[target] = np.load(os.path.join(dir_path, 'ROC_{}.npy'.format(target)), allow_pickle=True)
    return roc

control_roc = read_roc('../output/control')
miNNseq_roc = read_roc('../output/miNNseq')

# %%
for target in ['minor', 'important', 'full', 'all']:
    _miNNseq_roc = miNNseq_roc[target].item()

    _miNNseq_roc = pd.DataFrame(
        [
            _miNNseq_roc[method_name][2]
            for method_name in _miNNseq_roc.keys()
        ],
        index=_miNNseq_roc.keys()
    ).T

    _miNNseq_roc = pd.melt(_miNNseq_roc, value_vars=_miNNseq_roc.columns)

    methods = miNNseq_acc[target].columns
    pairs = [
        (methods[i], methods[j])
        for i in range(len(methods))
        for j in range(i + 1, len(methods))
    ]

    violinplot(
        _miNNseq_roc,
        x='variable',
        y='value',
        pairs=pairs,
        xlabel='',
        ylabel='ROC-AUC',
        output_path='../output/miNNseq/auc_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.438e-14 U_stat=1.140e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.562e-01 U_stat=9.735e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.443e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.059e-16 U_stat=2.500e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.133e-13 U_stat=1.560e+02
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.986e-16 U_stat=2.600e+01
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.156e+03
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.059e-16 U_stat=2.500e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.598e-15 U_stat=2.440e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.023e-15 U_stat=5.000e+01
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.059e-16 U_stat=2.500e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.910e-15 U_stat=2.451e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.701e-15 U_stat=2.453e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.328e-14 U_stat=2.407e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.389e-01 U_stat=1.628e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.182e-13 U_stat=1.225e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.290e-03 U_stat=7.485e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.000e+00 U_stat=1.260e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.269e-16 U_stat=2.497e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.776e-12 U_stat=1.820e+02
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.270e-15 U_stat=5.200e+01
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.924e-03 U_stat=7.355e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.977e-16 U_stat=2.466e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.136e-15 U_stat=7.200e+01
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.195e-16 U_stat=2.498e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.049e-16 U_stat=2.489e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.099e-15 U_stat=2.460e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.068e-15 U_stat=2.461e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.821e-04 U_stat=1.842e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.062e-04 U_stat=5.980e+02
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.144e-01 U_stat=9.300e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.238e-01 U_stat=9.630e+02
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.612e-16 U_stat=2.493e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.294e-05 U_stat=5.865e+02
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.049e-09 U_stat=3.425e+02
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.878e-04 U_stat=6.530e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.983e-16 U_stat=2.474e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.195e-16 U_stat=2.498e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.032e-12 U_stat=1.630e+02
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.701e-15 U_stat=2.445e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.926e-16 U_stat=2.483e+03
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.035e-12 U_stat=2.324e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.812e-15 U_stat=2.439e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.759e-10 U_stat=2.234e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AdaBoostClassifier vs. GradientBoostingClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=0.000e+00
# GradientBoostingClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.487e-07 U_stat=4.180e+02
# RandomForestClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.181e-01 U_stat=1.636e+03
# ExtraTreesClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# SVC vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.138e-14 U_stat=2.390e+03
# AdaBoostClassifier vs. RandomForestClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=0.000e+00
# GradientBoostingClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.209e-04 U_stat=6.210e+02
# RandomForestClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# ExtraTreesClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# AdaBoostClassifier vs. ExtraTreesClassifier: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=0.000e+00
# GradientBoostingClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# RandomForestClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AdaBoostClassifier vs. SVC: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.495e-01 U_stat=1.527e+03
# GradientBoostingClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.060e-16 U_stat=2.500e+03
# AdaBoostClassifier vs. OrderedModel: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.252e-14 U_stat=2.401e+03
