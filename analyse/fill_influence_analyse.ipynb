# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
def violinplot(data, x=None, y=None, hue=None, pairs=None, xlabel=None, ylabel=None, xticklabels=None, output_path: str = None, figsize: tuple = (24, 12)):
    sns.set_theme(style="whitegrid")

    fig, ax = plt.subplots(figsize=figsize)

    ax = sns.violinplot(data=data, x=x, y=y, hue=hue)

    if pairs:
        annotator = Annotator(ax, pairs, data=data, x=x, y=y, hue=hue)
        annotator.configure(test='Mann-Whitney', text_format='star')
        annotator.apply_and_annotate()

    plt.legend()
    plt.grid(False)

    if xlabel is not None:
        plt.xlabel(xlabel)
    if ylabel is not None:
        plt.ylabel(ylabel)
    if xticklabels:
        ax.set_xticklabels(labels=xticklabels)

    if output_path:
        plt.savefig(output_path, bbox_inches="tight")
    plt.show()

# %%
def read_accuracy(dir_path: str):
    acc = {}
    for target in ['effective', 'markedly effective', 'cured', 'all']:
        acc[target] = pd.read_csv(os.path.join(dir_path, 'accuracy_{}.csv'.format(target)), index_col=0)
    return acc

control_acc = read_accuracy('../output/control')
KNN_acc = read_accuracy('../output/data_fill/KNN')
rpca_acc = read_accuracy('../output/data_fill/rpca')

# %%
for target in ['effective', 'markedly effective', 'cured', 'all']:
    _control_acc = pd.melt(control_acc[target], value_vars=control_acc[target].columns)
    _KNN_acc = pd.melt(KNN_acc[target], value_vars=KNN_acc[target].columns)

    _control_acc['category'] = 'control'
    _KNN_acc['category'] = 'KNN'

    pairs = [
        ((method_name, 'control'), (method_name, 'KNN'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'KNN'), ('ExtraTreesClassifier', 'KNN')),
    ])

    violinplot(
        pd.concat([_control_acc, _KNN_acc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='Accuracy',
        output_path='../output/data_fill/KNN/accuracy_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.058e-08 U_stat=4.470e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.393e-04 U_stat=7.170e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.447e-03 U_stat=7.880e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:8.896e-02 U_stat=1.003e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.643e-01 U_stat=1.048e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.139e-04 U_stat=6.900e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.472e-01 U_stat=1.460e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.628e-03 U_stat=1.686e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.310e-08 U_stat=4.400e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.259e-03 U_stat=7.820e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.776e-07 U_stat=4.930e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.775e-08 U_stat=4.770e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.195e-03 U_stat=8.720e+02
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.050e-03 U_stat=8.590e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:6.883e-01 U_stat=1.192e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.767e-01 U_stat=1.292e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:6.914e-01 U_stat=1.192e+03
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.038e-01 U_stat=1.100e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.878e-01 U_stat=1.329e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.222e-01 U_stat=1.302e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.835e-01 U_stat=1.057e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.835e-01 U_stat=1.057e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:4.600e-01 U_stat=1.143e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.775e-01 U_stat=1.122e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.181e-05 U_stat=6.740e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:7.173e-01 U_stat=1.197e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.485e-03 U_stat=7.890e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.088e-03 U_stat=7.760e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.419e-02 U_stat=8.940e+02
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.488e-03 U_stat=8.470e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:9.803e-02 U_stat=1.490e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.469e-02 U_stat=1.604e+03

# %%
def read_roc(dir_path: str):
    roc = {}
    for target in ['effective', 'markedly effective', 'cured', 'all']:
        roc[target] = np.load(os.path.join(dir_path, 'ROC_{}.npy'.format(target)), allow_pickle=True)
    return roc

control_roc = read_roc('../output/control')
KNN_roc = read_roc('../output/data_fill/KNN')
rpca_roc = read_roc('../output/data_fill/rpca')

# %%
for target in ['effective', 'markedly effective', 'cured', 'all']:
    _control_roc = control_roc[target].item()
    _KNN_roc = KNN_roc[target].item()

    _control_roc = pd.DataFrame(
        [
            _control_roc[method_name][2]
            for method_name in _control_roc.keys()
        ],
        index=_control_roc.keys()
    ).T
    _KNN_roc = pd.DataFrame(
        [
            _KNN_roc[method_name][2]
            for method_name in _KNN_roc.keys()
        ],
        index=_KNN_roc.keys()
    ).T

    _control_roc = pd.melt(_control_roc, value_vars=_control_roc.columns)
    _KNN_roc = pd.melt(_KNN_roc, value_vars=_KNN_roc.columns)

    _control_roc['category'] = 'control'
    _KNN_roc['category'] = 'KNN'

    pairs = [
        ((method_name, 'control'), (method_name, 'KNN'))
        for method_name in control_acc[target].columns
    ]
    pairs.extend([
        (('RandomForestClassifier', 'control'), ('ExtraTreesClassifier', 'control')),
        (('RandomForestClassifier', 'KNN'), ('ExtraTreesClassifier', 'KNN')),
    ])

    violinplot(
        pd.concat([_control_roc, _KNN_roc]),
        x='variable',
        y='value',
        hue='category',
        pairs=pairs,
        xlabel='',
        ylabel='ROC-AUC',
        output_path='../output/data_fill/KNN/auc_comparison({}).pdf'.format(target),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.629e-06 U_stat=5.850e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.745e-06 U_stat=5.560e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.828e-03 U_stat=8.300e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.891e-02 U_stat=9.090e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:8.985e-01 U_stat=1.269e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.548e-05 U_stat=6.580e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:1.030e-01 U_stat=1.487e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.510e-02 U_stat=1.603e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.990e-05 U_stat=6.440e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.963e-02 U_stat=9.340e+02
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.860e-07 U_stat=5.050e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.521e-06 U_stat=5.520e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.538e-01 U_stat=1.115e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.270e-03 U_stat=8.350e+02
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:7.174e-01 U_stat=1.303e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.111e-02 U_stat=1.585e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.672e-02 U_stat=9.610e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.868e-01 U_stat=1.058e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.626e-01 U_stat=1.087e+03
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:9.094e-01 U_stat=1.233e+03
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.268e-01 U_stat=1.028e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.140e-01 U_stat=1.369e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:8.174e-02 U_stat=9.970e+02
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:2.931e-01 U_stat=1.097e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# GradientBoostingClassifier_control vs. GradientBoostingClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.268e-07 U_stat=5.160e+02
# AdaBoostClassifier_control vs. AdaBoostClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:5.510e-01 U_stat=1.337e+03
# RandomForestClassifier_control vs. RandomForestClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.178e-03 U_stat=8.340e+02
# ExtraTreesClassifier_control vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.748e-02 U_stat=9.620e+02
# SupervisedDBNClassification_control vs. SupervisedDBNClassification_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:4.545e-01 U_stat=1.141e+03
# SVC_control vs. SVC_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:1.606e-01 U_stat=1.046e+03
# RandomForestClassifier_control vs. ExtraTreesClassifier_control: Mann-Whitney-Wilcoxon test two-sided, P_val:2.995e-01 U_stat=1.401e+03
# RandomForestClassifier_KNN vs. ExtraTreesClassifier_KNN: Mann-Whitney-Wilcoxon test two-sided, P_val:3.280e-03 U_stat=1.677e+03
